# %% [markdown]
# # Introduction à la librairie Keras

# %% [markdown]
# Dans le TP précédent, vous avez implémenté l'apprentissage et l'inférence d'un réseau de neurones. En pratique, il est plus courant de faire appel à des librairies qui masquent la complexité de ces algorithmes (notamment le calcul des gradients, réalisé par différentiation automatique). Dans la suite, nous utiliserons pour les TPs la librairie ***Keras***. Dans un premier temps, pour ce TP nous allons détailler sur un exemple simple (le même que pour le TP précédent) les différentes étapes à mettre en place pour entraîner un réseau à l'aide de cette librairie.

# %% [markdown]
# Le bloc de code ci-dessous sera utile pour analyser l'évolution des performances au cours de l'apprentissage

# %%
def plot_training_analysis(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  #plt.figure()
  plt.subplots(1, 2, figsize=(10, 4))


  plt.subplot(1,2,1)
  plt.plot(epochs, acc, 'b', linestyle="--",label='Training acc')
  plt.plot(epochs, val_acc, 'g', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(epochs, loss, 'b', linestyle="--",label='Training loss')
  plt.plot(epochs, val_loss,'g', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %% [markdown]
# ## Exemple de classification binaire simple

# %% [markdown]
# Chargement des données (ce sont les mêmes que lors du dernier TP)

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

# Génération des données
x, y = datasets.make_blobs(n_samples=250, n_features=2, centers=2, center_box=(- 3, 3), random_state=1)
# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')

plt.xlabel('x1')
plt.ylabel('x2')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')

plt.legend()
plt.show()

# %% [markdown]
# Dans ce problème, les données $x^{(i)}$ sont les points, on a donc $x^{(i)} \in \mathbb{R}^2$. Les étiquettes $y^{(i)}$ correspondent à la couleur des points (bleue ou rouge), matérialisée par un label (0 ou 1).
#
# Pour résoudre le problème, on peut donc construire un perceptron monocouche à 2 entrées et une sortie.
#
# <center>
# <img src="https://drive.google.com/uc?id=1WfUL0fTE7fjeHMrlGjgH3b_3511ttnO8">
# </center>
#
# Il s'agit d'un problème de classification binaire, il faut donc utiliser une fonction d'activation **sigmoide** sur la couche de sortie.

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Définition du modèle, un simple perceptron monocouche.
model = Sequential() # Dans un modèle séquentiel, on peut ajouter les couches les unes après les autres
# Ici, on définit une seule couche connectant 2 neurones d'entrée à un neurone de sortie, portant une activation sigmoide
model.add(Dense(1, activation='sigmoid', input_dim=2)) # input_dim indique la dimension de la couche d'entrée, ici 2

model.summary() # affiche un résumé du modèle
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 3 (12.00 Byte)
# Trainable params: 3 (12.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Le résumé du modèle (*summary*) nous indique le nombre de paramètres du modèle, ici 3 : 2 poids synaptiques et un biais.
#
# Il nous faut maintenant choisir la fonction de coût : pour ce problème de classification binaire, le choix standard est l'entropie croisée binaire (*binary cross-entropy*).
#
# On choisit dans un premier temps un optimiseur standard, la descente de gradient stochastique.

# %%
from tensorflow.keras import optimizers

# Définition de l'optimiseur
sgd = optimizers.SGD(learning_rate=0.1) # On choisit la descente de gradient stochastique, avec un taux d'apprentissage de 0.1

# On définit ici, pour le modèle introduit plus tôt, l'optimiseur choisi (la SGD), la fonction de perte (ici
# l'entropie croisée binaire pour un problème de classification binaire) et les métriques que l'on veut observer pendant
# l'entraînement. L'accuracy désigne le pourcentage de bonnes classification, et est un indicateur plus simple à interpréter que l'entropie croisée.
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle avec des mini-batchs de taille 20, sur 15 epochs.
# Le paramètre validation_split signifie qu'on tire aléatoirement une partie des données
# (ici 20%) pour servir d'ensemble de validation
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15, batch_size=20)

plot_training_analysis(history)
# Out:
# Epoch 1/15
# 12/12 [==============================] - 1s 19ms/step - loss: 0.3514 - accuracy: 0.8444 - val_loss: 0.2876 - val_accuracy: 0.8800
# Epoch 2/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2340 - accuracy: 0.9156 - val_loss: 0.2228 - val_accuracy: 0.9200
# Epoch 3/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2017 - accuracy: 0.9289 - val_loss: 0.1940 - val_accuracy: 0.9200
# Epoch 4/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1852 - accuracy: 0.9422 - val_loss: 0.1774 - val_accuracy: 0.9600
# Epoch 5/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1744 - accuracy: 0.9556 - val_loss: 0.1635 - val_accuracy: 0.9600
# Epoch 6/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1658 - accuracy: 0.9511 - val_loss: 0.1547 - val_accuracy: 0.9600
# Epoch 7/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1592 - accuracy: 0.9511 - val_loss: 0.1477 - val_accuracy: 0.9600
# Epoch 8/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1533 - accuracy: 0.9556 - val_loss: 0.1433 - val_accuracy: 0.9600
# Epoch 9/15
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1485 - accuracy: 0.9600 - val_loss: 0.1373 - val_accuracy: 0.9600
# Epoch 10/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1439 - accuracy: 0.9644 - val_loss: 0.1324 - val_accuracy: 0.9600
# Epoch 11/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1395 - accuracy: 0.9644 - val_loss: 0.1286 - val_accuracy: 0.9600
# Epoch 12/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1357 - accuracy: 0.9689 - val_loss: 0.1247 - val_accuracy: 1.0000
# Epoch 13/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1325 - accuracy: 0.9689 - val_loss: 0.1212 - val_accuracy: 1.0000
# Epoch 14/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1294 - accuracy: 0.9644 - val_loss: 0.1179 - val_accuracy: 1.0000
# Epoch 15/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1265 - accuracy: 0.9600 - val_loss: 0.1139 - val_accuracy: 1.0000

# %% [markdown]
# L'apprentissage semble bien se passer : la perte d'apprentissage et la perte de validation décroissent au cours du temps, et l'accuracy est proche de 100% à la fin de l'apprentissage.
#
# La cellule suivante introduit une fonction permettant de visualiser la frontière de décision du modèle appris.

# %%
import numpy as np
def print_decision_boundaries(model, x, y):
  dx, dy = 0.1, 0.1
  y_grid, x_grid = np.mgrid[slice(np.min(x[:,1]), np.max(x[:,1]) + dy, dy),
                  slice(np.min(x[:,0]), np.max(x[:,0]) + dx, dx)]


  x_gen = np.concatenate((np.expand_dims(np.reshape(x_grid, (-1)),1),np.expand_dims(np.reshape(y_grid, (-1)),1)), axis=1)
  z_gen = model.predict(x_gen).reshape(x_grid.shape)

  z_min, z_max = 0, 1

  c = plt.pcolor(x_grid, y_grid, z_gen, cmap='RdBu', vmin=z_min, vmax=z_max)
  plt.colorbar(c)
  plt.plot(x[y==0,0], x[y==0,1], 'r.')
  plt.plot(x[y==1,0], x[y==1,1], 'b.')
  plt.show()

# %%
print_decision_boundaries(model, x_train, y_train)
# Out:
# 198/198 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Exemple de classification plus "complexe"

# %% [markdown]
# Les données de la section précédente sont linéairement séparables : un séparateur linéaire suffit à obtenir des bonnes performances, et un perceptron monocouche est donc bien adapté à la résolution de ce problème.
#
# Traitons maintenant un second problème légèrement plus
# complexe, non linéairement séparable.

# %%
x, y = datasets.make_gaussian_quantiles(n_samples=250, n_features=2, n_classes=2, random_state=1)
# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')

plt.xlabel('x1')
plt.ylabel('x2')

plt.legend()
plt.show()

# %% [markdown]
# **Travail à faire** : commencez par tester un perceptron monocouche comme nous l'avons vu précédemment.

# %%
print_decision_boundaries(model, x_train, y_train)
# Out:
# 96/96 [==============================] - 0s 1ms/step

# %% [markdown]
# Un perceptron monocouche ne permet que d'obtenir un séparateur linéaire, ce qui n'est pas suffisant pour apprendre à séparer ces données. La **capacité** du modèle est trop faible, et on est dans une situation de **sous-apprentissage** : la perte d'apprentissage ne diminue pas suffisamment, le modèle n'arrive pas à apprendre correctement l'ensemble d'apprentissage.
#
# Pour résoudre ce problème, il faut ajouter (au moins) une couche cachée au modèle. Voici un exemple ci-dessous, où l'on ajoute une couche cachée à 2 neurones.

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# On définit ici un perceptron multicouche à deux couches cachées.
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(1, activation='sigmoid'))

model.summary() # affiche un résumé du modèle

# Définition de l'optimiseur
sgd = optimizers.SGD(learning_rate=0.1)

# Fonction de coût et métrique
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=20)

# Affichage de l'évolution des métriques
plot_training_analysis(history)

# Visualisation du résultat
print_decision_boundaries(model, x_train, y_train)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_26 (Dense)            (None, 100)               300
#
#  dense_27 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 1s 29ms/step - loss: 0.6702 - accuracy: 0.5556 - val_loss: 0.6416 - val_accuracy: 0.5200
# Epoch 2/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6385 - accuracy: 0.5733 - val_loss: 0.6170 - val_accuracy: 0.6000
# Epoch 3/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6120 - accuracy: 0.6756 - val_loss: 0.5954 - val_accuracy: 0.6400
# Epoch 4/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5876 - accuracy: 0.6889 - val_loss: 0.5686 - val_accuracy: 0.8800
# Epoch 5/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5640 - accuracy: 0.8000 - val_loss: 0.5461 - val_accuracy: 0.8800
# Epoch 6/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5401 - accuracy: 0.8533 - val_loss: 0.5275 - val_accuracy: 0.9200
# Epoch 7/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5207 - accuracy: 0.8622 - val_loss: 0.5096 - val_accuracy: 0.9200
# Epoch 8/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5014 - accuracy: 0.8533 - val_loss: 0.4962 - val_accuracy: 0.8800
# Epoch 9/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4836 - accuracy: 0.8933 - val_loss: 0.4813 - val_accuracy: 0.8800
# Epoch 10/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4675 - accuracy: 0.9244 - val_loss: 0.4624 - val_accuracy: 0.9200
# Epoch 11/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.
# Epoch 45/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1998 - accuracy: 0.9689 - val_loss: 0.2322 - val_accuracy: 0.9200
# Epoch 46/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1948 - accuracy: 0.9600 - val_loss: 0.2585 - val_accuracy: 0.9200
# Epoch 47/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1968 - accuracy: 0.9733 - val_loss: 0.2245 - val_accuracy: 0.9200
# Epoch 48/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1914 - accuracy: 0.9644 - val_loss: 0.2293 - val_accuracy: 0.9200
# Epoch 49/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1871 - accuracy: 0.9644 - val_loss: 0.2366 - val_accuracy: 0.9200
# Epoch 50/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1868 - accuracy: 0.9778 - val_loss: 0.2191 - val_accuracy: 0.9200
# 96/96 [==============================] - 0s 1ms/step

# %% [markdown]
# **Travail à faire** : testez l'entraînement de ce modèle, et au besoin ajustez le nombre de neurones de la couche cachée pour obtenir de bons résultats.
#
# **Travail à faire** : testez également de remplacer l'optimiseur SGD par l'optimiseur [Adam](https://keras.io/api/optimizers/adam/)

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# On définit ici un perceptron multicouche à deux couches cachées.
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(1, activation='sigmoid'))

model.summary() # affiche un résumé du modèle

# Définition de l'optimiseur
sgd = optimizers.Adam(learning_rate=0.1)

# Fonction de coût et métrique
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=20)

# Affichage de l'évolution des métriques
plot_training_analysis(history)

# Visualisation du résultat
print_decision_boundaries(model, x_train, y_train)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 100)               300
#
#  dense_29 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 1s 20ms/step - loss: 0.4904 - accuracy: 0.7422 - val_loss: 0.2930 - val_accuracy: 0.8800
# Epoch 2/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2279 - accuracy: 0.8933 - val_loss: 0.2234 - val_accuracy: 0.9200
# Epoch 3/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2247 - accuracy: 0.9244 - val_loss: 0.1035 - val_accuracy: 1.0000
# Epoch 4/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2892 - accuracy: 0.8978 - val_loss: 0.2192 - val_accuracy: 0.9200
# Epoch 5/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5199 - accuracy: 0.8711 - val_loss: 0.6050 - val_accuracy: 0.8400
# Epoch 6/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3969 - accuracy: 0.8533 - val_loss: 0.3587 - val_accuracy: 0.8800
# Epoch 7/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2935 - accuracy: 0.8756 - val_loss: 0.1963 - val_accuracy: 0.9200
# Epoch 8/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2006 - accuracy: 0.9289 - val_loss: 0.1913 - val_accuracy: 0.8800
# Epoch 9/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1285 - accuracy: 0.9600 - val_loss: 0.1636 - val_accuracy: 0.9200
# Epoch 10/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1245 - accuracy: 0.9511 - val_loss: 0.3341 - val_accuracy: 0.8800
# Epoch 11/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2339 - accuracy: 0.9022 - val_loss: 0.0840 - val_accuracy: 1.0000
# Epoch 12/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1647 - accuracy: 0.9244 - val_loss: 0.1853 - val_accuracy: 0.9200
# Epoch 13/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1731 - accuracy: 0.9378 - val_loss: 0.1551 - val_accuracy: 0.8800
# Epoch 14/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1873 - accuracy: 0.9378 - val_loss: 0.4666 - val_accuracy: 0.8000
# Epoch 15/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1691 - accuracy: 0.9289 - val_loss: 0.0799 - val_accuracy: 0.9600
# Epoch 16/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1021 - accuracy: 0.9467 - val_loss: 0.2383 - val_accuracy: 0.8800
# Epoch 17/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2066 - accuracy: 0.9378 - val_loss: 0.4937 - val_accuracy: 0.9200
# Epoch 18/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2385 - accuracy: 0.9289 - val_loss: 0.1989 - val_accuracy: 0.9200
# Epoch 19/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1577 - accuracy: 0.9289 - val_loss: 0.2312 - val_accuracy: 0.8800
# Epoch 20/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2664 - accuracy: 0.9022 - val_loss: 0.4389 - val_accuracy: 0.8400
# Epoch 21/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2005 - accuracy: 0.9244 - val_loss: 0.1146 - val_accuracy: 0.9600
# Epoch 22/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0928 - accuracy: 0.9644 - val_loss: 0.1728 - val_accuracy: 0.9200
# Epoch 23/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9733 - val_loss: 0.0995 - val_accuracy: 0.9600
# Epoch 24/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0873 - accuracy: 0.9689 - val_loss: 0.0672 - val_accuracy: 0.9600
# Epoch 25/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1627 - accuracy: 0.9333 - val_loss: 0.2601 - val_accuracy: 0.9200
# Epoch 26/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0692 - accuracy: 0.9689 - val_loss: 0.1122 - val_accuracy: 0.9200
# Epoch 27/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0552 - accuracy: 0.9867 - val_loss: 0.1546 - val_accuracy: 0.9200
# Epoch 28/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0635 - accuracy: 0.9733 - val_loss: 0.1397 - val_accuracy: 0.9200
# Epoch 29/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0570 - accuracy: 0.9733 - val_loss: 0.2481 - val_accuracy: 0.9200
# Epoch 30/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0575 - accuracy: 0.9822 - val_loss: 0.0997 - val_accuracy: 0.9200
# Epoch 31/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0526 - accuracy: 0.9911 - val_loss: 0.1502 - val_accuracy: 0.9200
# Epoch 32/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0529 - accuracy: 0.9822 - val_loss: 0.2304 - val_accuracy: 0.9200
# Epoch 33/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1093 - accuracy: 0.9733 - val_loss: 0.1819 - val_accuracy: 0.9200
# Epoch 34/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1634 - accuracy: 0.9200 - val_loss: 0.5994 - val_accuracy: 0.8800
# Epoch 35/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2692 - accuracy: 0.9378 - val_loss: 0.1736 - val_accuracy: 0.9600
# Epoch 36/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1682 - accuracy: 0.9156 - val_loss: 0.1240 - val_accuracy: 0.9200
# Epoch 37/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0936 - accuracy: 0.9600 - val_loss: 0.3449 - val_accuracy: 0.8800
# Epoch 38/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1340 - accuracy: 0.9333 - val_loss: 0.0753 - val_accuracy: 1.0000
# Epoch 39/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0693 - accuracy: 0.9733 - val_loss: 0.1116 - val_accuracy: 0.9600
# Epoch 40/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0634 - accuracy: 0.9733 - val_loss: 0.1568 - val_accuracy: 0.9200
# Epoch 41/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0639 - accuracy: 0.9733 - val_loss: 0.0886 - val_accuracy: 0.9600
# Epoch 42/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0608 - accuracy: 0.9822 - val_loss: 0.1689 - val_accuracy: 0.9200
# Epoch 43/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0719 - accuracy: 0.9822 - val_loss: 0.1893 - val_accuracy: 0.8800
# Epoch 44/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0784 - accuracy: 0.9644 - val_loss: 0.3304 - val_accuracy: 0.8800
# Epoch 45/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1169 - accuracy: 0.9556 - val_loss: 0.1146 - val_accuracy: 0.9200
# Epoch 46/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0852 - accuracy: 0.9600 - val_loss: 0.3490 - val_accuracy: 0.8800
# Epoch 47/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0804 - accuracy: 0.9556 - val_loss: 0.3269 - val_accuracy: 0.8800
# Epoch 48/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0681 - accuracy: 0.9689 - val_loss: 0.1387 - val_accuracy: 0.9200
# Epoch 49/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1015 - accuracy: 0.9867 - val_loss: 0.1839 - val_accuracy: 0.9200
# Epoch 50/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0400 - accuracy: 0.9911 - val_loss: 0.2114 - val_accuracy: 0.9200
# 96/96 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Sur-apprentissage et régularisation

# %% [markdown]
# Dans cette section, nous commençons par altérer un peu les données afin qu'elles comportent du "bruit" : la frontière de décision entre données bleues et rouges n'est plus si claire.

# %%
x, y = datasets.make_gaussian_quantiles(n_samples=250, n_features=2, n_classes=2, random_state=1)
x[y==0] = x[y==0]*1.2
x[y==1] = x[y==1]*0.8

# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')

plt.xlabel('x1')
plt.ylabel('x2')

plt.legend()

plt.show()

# %% [markdown]
# **Travail à faire** : Reprenez le modèle à une couche cachée construit précédemment et vérifiez que ce modèle arrive toujours à apprendre une solution satisfaisante.

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# On définit ici un perceptron multicouche à deux couches cachées.
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(1, activation='sigmoid'))

model.summary() # affiche un résumé du modèle

# Définition de l'optimiseur
sgd = optimizers.Adam(learning_rate=0.1)

# Fonction de coût et métrique
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=20)

# Affichage de l'évolution des métriques
plot_training_analysis(history)

# Visualisation du résultat
print_decision_boundaries(model, x_train, y_train)
# Out:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_108 (Dense)           (None, 100)               300
#
#  dense_109 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 401 (1.57 KB)
# Trainable params: 401 (1.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 1s 20ms/step - loss: 0.6925 - accuracy: 0.4711 - val_loss: 0.6607 - val_accuracy: 0.5200
# Epoch 2/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6589 - accuracy: 0.5689 - val_loss: 0.6470 - val_accuracy: 0.6800
# Epoch 3/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6447 - accuracy: 0.6356 - val_loss: 0.6296 - val_accuracy: 0.6400
# Epoch 4/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6267 - accuracy: 0.6667 - val_loss: 0.6162 - val_accuracy: 0.6400
# Epoch 5/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6096 - accuracy: 0.7156 - val_loss: 0.5965 - val_accuracy: 0.7200
# Epoch 6/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5899 - accuracy: 0.7156 - val_loss: 0.5718 - val_accuracy: 0.7600
# Epoch 7/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5731 - accuracy: 0.7511 - val_loss: 0.5589 - val_accuracy: 0.7200
# Epoch 8/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5570 - accuracy: 0.7467 - val_loss: 0.5470 - val_accuracy: 0.7200
# Epoch 9/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5462 - accuracy: 0.7422 - val_loss: 0.5241 - val_accuracy: 0.8000
# Epoch 10/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5242 - accuracy: 0.7644 - val_loss: 0.5186 - val_accuracy: 0.8000
# Epoch 11/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5117 - accuracy: 0.7644 - val_loss: 0.5178 - val_accuracy: 0.6400
# Epoch 12/50
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4997 - accuracy: 0.7467 - val_loss: 0.4958 - val_accuracy: 0.8000
# Epoch 13/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4946 - accuracy: 0.7289 - val_loss: 0.5044 - val_accuracy: 0.7200
# Epoch 14/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4827 - accuracy: 0.7511 - val_loss: 0.4918 - val_accuracy: 0.8000
# Epoch 15/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4854 - accuracy: 0.7600 - val_loss: 0.4817 - val_accuracy: 0.8000
# Epoch 16/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4720 - accuracy: 0.7111 - val_loss: 0.5079 - val_accuracy: 0.7200
# Epoch 17/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4692 - accuracy: 0.7244 - val_loss: 0.4889 - val_accuracy: 0.7600
# Epoch 18/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4707 - accuracy: 0.7600 - val_loss: 0.4704 - val_accuracy: 0.7600
# Epoch 19/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4656 - accuracy: 0.7467 - val_loss: 0.4942 - val_accuracy: 0.7200
# Epoch 20/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4559 - accuracy: 0.7644 - val_loss: 0.4604 - val_accuracy: 0.8000
# Epoch 21/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4550 - accuracy: 0.7644 - val_loss: 0.4788 - val_accuracy: 0.7200
# Epoch 22/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4522 - accuracy: 0.7200 - val_loss: 0.4684 - val_accuracy: 0.7200
# Epoch 23/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4487 - accuracy: 0.7156 - val_loss: 0.4842 - val_accuracy: 0.7200
# Epoch 24/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4469 - accuracy: 0.7378 - val_loss: 0.4785 - val_accuracy: 0.7200
# Epoch 25/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4480 - accuracy: 0.7467 - val_loss: 0.4601 - val_accuracy: 0.7200
# Epoch 26/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4473 - accuracy: 0.7467 - val_loss: 0.4836 - val_accuracy: 0.7200
# Epoch 27/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4601 - accuracy: 0.7511 - val_loss: 0.4694 - val_accuracy: 0.7200
# Epoch 28/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4416 - accuracy: 0.7378 - val_loss: 0.4906 - val_accuracy: 0.7600
# Epoch 29/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4423 - accuracy: 0.7378 - val_loss: 0.4746 - val_accuracy: 0.7200
# Epoch 30/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4454 - accuracy: 0.7644 - val_loss: 0.4696 - val_accuracy: 0.6800
# Epoch 31/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4352 - accuracy: 0.7378 - val_loss: 0.5002 - val_accuracy: 0.6800
# Epoch 32/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4455 - accuracy: 0.7333 - val_loss: 0.4691 - val_accuracy: 0.7200
# Epoch 33/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4442 - accuracy: 0.7333 - val_loss: 0.4728 - val_accuracy: 0.7200
# Epoch 34/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4397 - accuracy: 0.7422 - val_loss: 0.4621 - val_accuracy: 0.6800
# Epoch 35/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4394 - accuracy: 0.7378 - val_loss: 0.4869 - val_accuracy: 0.7600
# Epoch 36/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4385 - accuracy: 0.7378 - val_loss: 0.4773 - val_accuracy: 0.6800
# Epoch 37/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4517 - accuracy: 0.7600 - val_loss: 0.4704 - val_accuracy: 0.7200
# Epoch 38/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4356 - accuracy: 0.7422 - val_loss: 0.4996 - val_accuracy: 0.6800
# Epoch 39/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4396 - accuracy: 0.7511 - val_loss: 0.4632 - val_accuracy: 0.6800
# Epoch 40/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4431 - accuracy: 0.7244 - val_loss: 0.4832 - val_accuracy: 0.7600
# Epoch 41/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4423 - accuracy: 0.7333 - val_loss: 0.4746 - val_accuracy: 0.7200
# Epoch 42/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4364 - accuracy: 0.7422 - val_loss: 0.4822 - val_accuracy: 0.7200
# Epoch 43/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4402 - accuracy: 0.7422 - val_loss: 0.4733 - val_accuracy: 0.6800
# Epoch 44/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4396 - accuracy: 0.7378 - val_loss: 0.4756 - val_accuracy: 0.7200
# Epoch 45/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4444 - accuracy: 0.7333 - val_loss: 0.4891 - val_accuracy: 0.7200
# Epoch 46/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4433 - accuracy: 0.7244 - val_loss: 0.4865 - val_accuracy: 0.7200
# Epoch 47/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4303 - accuracy: 0.7378 - val_loss: 0.4677 - val_accuracy: 0.7200
# Epoch 48/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4503 - accuracy: 0.7422 - val_loss: 0.5150 - val_accuracy: 0.7200
# Epoch 49/50
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4395 - accuracy: 0.7511 - val_loss: 0.4743 - val_accuracy: 0.7200
# Epoch 50/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4367 - accuracy: 0.7467 - val_loss: 0.4776 - val_accuracy: 0.7200
# 62/62 [==============================] - 0s 2ms/step

# %% [markdown]
# L'avantage de ce modèle à une couche cachée est qu'il reste assez simple : il n'a pas une capacité suffisante pour chercher à expliquer à tout prix la distribution des données d'apprentissage. L'accuracy plafonne vers 75% sur l'ensemble d'apprentissage, ce qui semble évoquer du sous-apprentissage, mais en réalité le modèle est satisfaisant car l'accuracy de validation est elle autour de 70%.
#
#
# Une piste d'amélioration pourrait consister à augmenter la capacité du modèle afin d'obtenir de meilleures performances sur l'ensemble d'apprentissage.
#
# **Travail à faire** : Augmentez la capacité du modèle (nombre de couches cachées, nombre de neurones par couche) de sorte d'obtenir une accuracy d'apprentissage d'environ 90%. Qu'observez-vous sur l'accuracy de validation ?

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# On définit ici un perceptron multicouche à deux couches cachées.
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(100, activation='relu', input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(100, activation='relu', input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(100, activation='relu', input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(100, activation='relu', input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(1, activation='sigmoid'))

model.summary() # affiche un résumé du modèle

# Définition de l'optimiseur
sgd = optimizers.Adam(learning_rate=0.001)

# Fonction de coût et métrique
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=200, batch_size=20)

# Affichage de l'évolution des métriques
plot_training_analysis(history)

# Visualisation du résultat
print_decision_boundaries(model, x_train, y_train)
# Out:
# Model: "sequential_46"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_160 (Dense)           (None, 100)               300
#
#  dense_161 (Dense)           (None, 100)               10100
#
#  dense_162 (Dense)           (None, 100)               10100
#
#  dense_163 (Dense)           (None, 100)               10100
#
#  dense_164 (Dense)           (None, 100)               10100
#
#  dense_165 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 40801 (159.38 KB)
# Trainable params: 40801 (159.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 12/12 [==============================] - 2s 26ms/step - loss: 0.6764 - accuracy: 0.5600 - val_loss: 0.6611 - val_accuracy: 0.5200
# Epoch 2/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6576 - accuracy: 0.5511 - val_loss: 0.6488 - val_accuracy: 0.6400
# Epoch 3/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6361 - accuracy: 0.6356 - val_loss: 0.6139 - val_accuracy: 0.6800
# Epoch 4/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6051 - accuracy: 0.6844 - val_loss: 0.5925 - val_accuracy: 0.7600
# Epoch 5/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5722 - accuracy: 0.7511 - val_loss: 0.5625 - val_accuracy: 0.6400
# Epoch 6/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5338 - accuracy: 0.7200 - val_loss: 0.4950 - val_accuracy: 0.7600
# Epoch 7/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4900 - accuracy: 0.7467 - val_loss: 0.4816 - val_accuracy: 0.7600
# Epoch 8/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5168 - accuracy: 0.7378 - val_loss: 0.5661 - val_accuracy: 0.6800
# Epoch 9/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4571 - accuracy: 0.7733 - val_loss: 0.4927 - val_accuracy: 0.7200
# Epoch 10/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4811 - accuracy: 0.7467 - val_loss: 0.4911 - val_accuracy: 0.6800
# Epoch 11/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4874 - accuracy: 0.7733 - val_loss: 0.5638 - val_accuracy: 0.7200
# Epoch 12/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4550 - accuracy: 0.7333 - val_loss: 0.4611 - val_accuracy: 0.6800
# Epoch 13/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4645 - accuracy: 0.7511 - val_loss: 0.4965 - val_accuracy: 0.6800
# Epoch 14/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4636 - accuracy: 0.7378 - val_loss: 0.5023 - val_accuracy: 0.7200
# Epoch 15/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4582 - accuracy: 0.7733 - val_loss: 0.5020 - val_accuracy: 0.7600
# Epoch 16/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4381 - accuracy: 0.7689 - val_loss: 0.5359 - val_accuracy: 0.7200
# Epoch 17/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4324 - accuracy: 0.7822 - val_loss: 0.4950 - val_accuracy: 0.7200
# Epoch 18/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4435 - accuracy: 0.7644 - val_loss: 0.5030 - val_accuracy: 0.6800
# Epoch 19/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4408 - accuracy: 0.7778 - val_loss: 0.5236 - val_accuracy: 0.6800
# Epoch 20/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4342 - accuracy: 0.7422 - val_loss: 0.4879 - val_accuracy: 0.7200
# Epoch 21/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4294 - accuracy: 0.7644 - val_loss: 0.5123 - val_accuracy: 0.7200
# Epoch 22/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4305 - accuracy: 0.7822 - val_loss: 0.4564 - val_accuracy: 0.6800
# Epoch 23/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4308 - accuracy: 0.7822 - val_loss: 0.4728 - val_accuracy: 0.6400
# Epoch 24/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4238 - accuracy: 0.7600 - val_loss: 0.5036 - val_accuracy: 0.6800
# Epoch 25/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.4258 - accuracy: 0.7600 - val_loss: 0.4722 - val_accuracy: 0.7600
# Epoch 26/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.4306 - accuracy: 0.7778 - val_loss: 0.5001 - val_accuracy: 0.6800
# Epoch 27/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.
200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2067 - accuracy: 0.8711 - val_loss: 1.3378 - val_accuracy: 0.6400
# Epoch 181/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1996 - accuracy: 0.8756 - val_loss: 1.2389 - val_accuracy: 0.6400
# Epoch 182/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2097 - accuracy: 0.8800 - val_loss: 1.3166 - val_accuracy: 0.6000
# Epoch 183/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2084 - accuracy: 0.8667 - val_loss: 1.1586 - val_accuracy: 0.6400
# Epoch 184/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1863 - accuracy: 0.8978 - val_loss: 1.3855 - val_accuracy: 0.5200
# Epoch 185/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1951 - accuracy: 0.8844 - val_loss: 1.4747 - val_accuracy: 0.5600
# Epoch 186/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1947 - accuracy: 0.9067 - val_loss: 1.2086 - val_accuracy: 0.6000
# Epoch 187/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1898 - accuracy: 0.9067 - val_loss: 1.4550 - val_accuracy: 0.5600
# Epoch 188/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2201 - accuracy: 0.8711 - val_loss: 1.4547 - val_accuracy: 0.6000
# Epoch 189/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2278 - accuracy: 0.8711 - val_loss: 0.8278 - val_accuracy: 0.7200
# Epoch 190/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2908 - accuracy: 0.8711 - val_loss: 1.2700 - val_accuracy: 0.6400
# Epoch 191/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2224 - accuracy: 0.8711 - val_loss: 1.1228 - val_accuracy: 0.6400
# Epoch 192/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1779 - accuracy: 0.9111 - val_loss: 1.3468 - val_accuracy: 0.5600
# Epoch 193/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1786 - accuracy: 0.9022 - val_loss: 1.2849 - val_accuracy: 0.5600
# Epoch 194/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1787 - accuracy: 0.9111 - val_loss: 1.2298 - val_accuracy: 0.6400
# Epoch 195/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2003 - accuracy: 0.9156 - val_loss: 1.4107 - val_accuracy: 0.5200
# Epoch 196/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2021 - accuracy: 0.9067 - val_loss: 1.2839 - val_accuracy: 0.6000
# Epoch 197/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1943 - accuracy: 0.8933 - val_loss: 1.4576 - val_accuracy: 0.6000
# Epoch 198/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1854 - accuracy: 0.9111 - val_loss: 1.2110 - val_accuracy: 0.6400
# Epoch 199/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2037 - accuracy: 0.8933 - val_loss: 1.2248 - val_accuracy: 0.6400
# Epoch 200/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3109 - accuracy: 0.8533 - val_loss: 1.5631 - val_accuracy: 0.5600
# 62/62 [==============================] - 0s 2ms/step

# %% [markdown]
# On observe du **sur-apprentissage** ! L'accuracy d'entrainement est élevée, mais l'accuracy de validation est faible. On doit alors chercher à limiter le sur-apprentissage, et pour ce faire on peut utiliser des techniques de régularisation. Une des techniques vues en cours consiste à appliquer une pénalité sur la norme des paramètres du modèle. Ainsi, plutôt que de minimiser une fonction objectif $J(\theta)$ classique :
# $$ J(\theta) = \frac{1}{n} \sum_{i=1}^{n} \text{loss}(y^{(i)}, \hat{y}^{(i)}) $$
#
# on minimise plutôt :
# $$ J(\theta) = \frac{1}{n} \sum_{i=1}^{n} \text{loss}(y^{(i)}, \hat{y}^{(i)}) + \lambda \sum_{j=1}^M \theta_j^2 $$
#
# où $M$ désigne le nombre de paramètres (poids synaptiques et biais) du réseau, $\theta$ désigne les paramètres du réseau.
#
# En pratique il suffit d'appliquer cette pénalisation aux poids synaptiques seuls (car ils sont beaucoup plus nombreux).
#
# La librairie Keras permet d'appliquer de la régularisation à n'importe quelle couche, [comme décrit sur cette page.](https://keras.io/api/layers/regularizers/)
#
# **Travail à faire**: Reprenez votre réseau précédent (avec lequel on obtenait du sur-apprentissage) et intégrez de la régularisation pour limiter le sur-apprentissage.

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras import regularizers

# On définit ici un perceptron multicouche à deux couches cachées.
model = Sequential()
model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.L2(5e-3), input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.L2(5e-3), input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.L2(5e-3), input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.L2(5e-3), input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones
model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.L2(5e-3), input_dim=2)) # La première couche cachée connecte les deux neurones d'entrée à deux neurones

model.add(Dense(1, activation='sigmoid'))

model.summary() # affiche un résumé du modèle

# Définition de l'optimiseur
sgd = optimizers.Adam(learning_rate=0.001)


# Fonction de coût et métrique
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=200, batch_size=20)

# Affichage de l'évolution des métriques
plot_training_analysis(history)

# Visualisation du résultat
print_decision_boundaries(model, x_train, y_train)
# Out:
# Model: "sequential_50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_184 (Dense)           (None, 100)               300
#
#  dense_185 (Dense)           (None, 100)               10100
#
#  dense_186 (Dense)           (None, 100)               10100
#
#  dense_187 (Dense)           (None, 100)               10100
#
#  dense_188 (Dense)           (None, 100)               10100
#
#  dense_189 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 40801 (159.38 KB)
# Trainable params: 40801 (159.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 12/12 [==============================] - 2s 26ms/step - loss: 2.5617 - accuracy: 0.4667 - val_loss: 2.3513 - val_accuracy: 0.4800
# Epoch 2/200
# 12/12 [==============================] - 0s 8ms/step - loss: 2.2096 - accuracy: 0.5111 - val_loss: 2.0374 - val_accuracy: 0.5200
# Epoch 3/200
# 12/12 [==============================] - 0s 5ms/step - loss: 1.9171 - accuracy: 0.5467 - val_loss: 1.7713 - val_accuracy: 0.6000
# Epoch 4/200
# 12/12 [==============================] - 0s 7ms/step - loss: 1.6761 - accuracy: 0.6356 - val_loss: 1.5513 - val_accuracy: 0.6800
# Epoch 5/200
# 12/12 [==============================] - 0s 10ms/step - loss: 1.4696 - accuracy: 0.6756 - val_loss: 1.3679 - val_accuracy: 0.7200
# Epoch 6/200
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2998 - accuracy: 0.7022 - val_loss: 1.2123 - val_accuracy: 0.7600
# Epoch 7/200
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1591 - accuracy: 0.7333 - val_loss: 1.0967 - val_accuracy: 0.6800
# Epoch 8/200
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0385 - accuracy: 0.7600 - val_loss: 0.9856 - val_accuracy: 0.7200
# Epoch 9/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9341 - accuracy: 0.7689 - val_loss: 0.8788 - val_accuracy: 0.8000
# Epoch 10/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8496 - accuracy: 0.7644 - val_loss: 0.8807 - val_accuracy: 0.7200
# Epoch 11/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8028 - accuracy: 0.7022 - val_loss: 0.7790 - val_accuracy: 0.6800
# Epoch 12/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7467 - accuracy: 0.7422 - val_loss: 0.7804 - val_accuracy: 0.7200
# Epoch 13/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7305 - accuracy: 0.7333 - val_loss: 0.7037 - val_accuracy: 0.7600
# Epoch 14/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7106 - accuracy: 0.7378 - val_loss: 0.7381 - val_accuracy: 0.7200
# Epoch 15/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6791 - accuracy: 0.7244 - val_loss: 0.6787 - val_accuracy: 0.7600
# Epoch 16/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6676 - accuracy: 0.7156 - val_loss: 0.6314 - val_accuracy: 0.7600
# Epoch 17/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.
200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.5119 - accuracy: 0.7689 - val_loss: 0.5439 - val_accuracy: 0.6400
# Epoch 198/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5010 - accuracy: 0.7467 - val_loss: 0.5599 - val_accuracy: 0.7200
# Epoch 199/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4953 - accuracy: 0.7600 - val_loss: 0.5187 - val_accuracy: 0.6400
# Epoch 200/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4898 - accuracy: 0.7867 - val_loss: 0.5754 - val_accuracy: 0.7600
# 62/62 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Problème à 3 classes
#
# Tous les problèmes que nous avons abordés jusqu'à maintenant étaient des problèmes de classification binaire (fonction d'activation sigmoide).
#
# Dans cette section nous définissons un jeu de données comportant trois classes.

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

# Génération des données
x, y = datasets.make_blobs(n_samples=500, n_features=2, centers=3, center_box=(- 5, 5), random_state=3)
# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')
plt.plot(x_train[y_train==2,0], x_train[y_train==2,1], 'g.', label='Apprentissage, classe 2')

plt.xlabel('x1')
plt.ylabel('x2')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')
plt.plot(x_test[y_test==2,0], x_test[y_test==2,1], 'g+', label='Test, classe 1')

plt.legend()
plt.show()

# %% [markdown]
# La fonction ci-dessous permet d'afficher les frontières de décision apprises par le modèle.

# %%
def print_decision_boundaries_3classes(model, x, y):
    # Adjust step sizes to match the input data
    dx = (np.max(x[:, 0]) - np.min(x[:, 0])) / 100
    dy = (np.max(x[:, 1]) - np.min(x[:, 1])) / 100

    # Create a grid with adjusted step sizes
    y_grid, x_grid = np.mgrid[slice(np.min(x[:, 1]), np.max(x[:, 1]) + dy, dy),
                               slice(np.min(x[:, 0]), np.max(x[:, 0]) + dx, dx)]

    # Generate points for prediction
    x_gen = np.stack((x_grid.ravel(), y_grid.ravel()), axis=-1)
    y_pred_gen = np.argmax(model.predict(x_gen), axis=1)
    z_gen = y_pred_gen.reshape(x_grid.shape)

    # Define color range
    z_min, z_max = 0, 2

    # Plot decision boundaries
    c = plt.pcolor(x_grid, y_grid, z_gen, cmap='brg', vmin=z_min, vmax=z_max, alpha=0.5)
    plt.colorbar(c)

    # Plot data points for each class
    plt.plot(x[y == 0, 0], x[y == 0, 1], 'bo', label='Class 0')
    plt.plot(x[y == 1, 0], x[y == 1, 1], 'ro', label='Class 1')
    plt.plot(x[y == 2, 0], x[y == 2, 1], 'go', label='Class 2')

    # Add legend
    plt.legend()
    plt.show()

# %% [markdown]
# Lorsque les données appartiennent à plus de deux classes, il est nécessaire de formater les labels sous la forme de *one-hot vectors*, c'est-à-dire de de vecteurs constitués de 0 et d'un 1 à l'indice de la classe correspondante.
#
# Ainsi, pour un problème à 3 classes :
# - si $x^{(i)}$ appartient à la classe 0, $y^{(i)} = [1, 0, 0]^T$
# - si $x^{(i)}$ appartient à la classe 1, $y^{(i)} = [0, 1, 0]^T$
# - si $x^{(i)}$ appartient à la classe 2, $y^{(i)} = [0, 0, 1]^T$
#
# Dans le jeu de données introduit plus haut, les labels $y \in \{0, 1, 2\}$. Pour les convertir au format *one-hot*, vous pouvez utiliser la fonction [to_categorical](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical).
#
# **Travail à faire**: Construisez un perceptron monocouche capable de résoudre ce problème de classification à 3 classes.

# %%
y_modif_train = tensorflow.keras.utils.to_categorical(y_train, num_classes =3)
y_modif_test = tensorflow.keras.utils.to_categorical(y_test, num_classes =3)

# %%
import tensorflow

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras import regularizers

model.add(Dense(3, activation='softmax', input_dim=2))

model.summary() # affiche un résumé du modèle

# Définition de l'optimiseur
sgd = optimizers.Adam(learning_rate=0.001)


# Fonction de coût et métrique
model.compile(optimizer=sgd,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle
history = model.fit(x_train, y_modif_train, validation_data=(x_test, y_modif_test), epochs=50, batch_size=20)

# Affichage de l'évolution des métriques
plot_training_analysis(history)

# Visualisation du résultat
print_decision_boundaries_3classes(model, x_train, y_train)
# Out:
# Model: "sequential_50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_184 (Dense)           (None, 100)               300
#
#  dense_185 (Dense)           (None, 100)               10100
#
#  dense_186 (Dense)           (None, 100)               10100
#
#  dense_187 (Dense)           (None, 100)               10100
#
#  dense_188 (Dense)           (None, 100)               10100
#
#  dense_189 (Dense)           (None, 1)                 101
#
#  dense_190 (Dense)           (None, 1)                 2
#
#  dense_191 (Dense)           (None, 1)                 2
#
#  dense_192 (Dense)           (None, 3)                 6
#
#  dense_193 (Dense)           (None, 3)                 12
#
#  dense_194 (Dense)           (None, 3)                 12
#
#  dense_195 (Dense)           (None, 3)                 12
#
#  dense_196 (Dense)           (None, 3)                 12
#
#  dense_197 (Dense)           (None, 3)                 12
#
#  dense_198 (Dense)           (None, 3)                 12
#
#  dense_199 (Dense)           (None, 3)                 12
#
#  dense_200 (Dense)           (None, 3)                 12
#
# =================================================================
# Total params: 40907 (159.79 KB)
# Trainable params: 40907 (159.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 23/23 [==============================] - 4s 21ms/step - loss: 1.1045 - accuracy: 0.3333 - val_loss: 1.1097 - val_accuracy: 0.3200
# Epoch 2/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.1029 - accuracy: 0.3333 - val_loss: 1.1060 - val_accuracy: 0.3200
# Epoch 3/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.1012 - accuracy: 0.3333 - val_loss: 1.1045 - val_accuracy: 0.3200
# Epoch 4/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.1004 - accuracy: 0.3333 - val_loss: 1.1036 - val_accuracy: 0.3200
# Epoch 5/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0999 - accuracy: 0.3333 - val_loss: 1.1019 - val_accuracy: 0.3200
# Epoch 6/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0994 - accuracy: 0.3333 - val_loss: 1.1012 - val_accuracy: 0.3200
# Epoch 7/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0990 - accuracy: 0.3333 - val_loss: 1.1006 - val_accuracy: 0.3200
# Epoch 8/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0994 - accuracy: 0.3333 - val_loss: 1.0996 - val_accuracy: 0.3200
# Epoch 9/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.1001 - val_accuracy: 0.3200
# Epoch 10/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0991 - accuracy: 0.3333 - val_loss: 1.0995 - val_accuracy: 0.3200
# Epoch 11/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0995 - val_accuracy: 0.3200
# Epoch 12/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0989 - accuracy: 0.3022 - val_loss: 1.0994 - val_accuracy: 0.3200
# Epoch 13/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0988 - accuracy: 0.3378 - val_loss: 1.0995 - val_accuracy: 0.3200
# Epoch 14/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0992 - val_accuracy: 0.3200
# Epoch 15/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0987 - accuracy: 0.3244 - val_loss: 1.0991 - val_accuracy: 0.3200
# Epoch 16/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0987 - accuracy: 0.3267 - val_loss: 1.0990 - val_accuracy: 0.3200
# Epoch 17/50
# 23/23 [==============================] - 0s 10ms/step - loss: 1.0989 - accuracy: 0.3000 - val_loss: 1.0990 - val_accuracy: 0.3200
# Epoch 18/50
# 23/23 [==============================] - 0s 10ms/step - loss: 1.0988 - accuracy: 0.3156 - val_loss: 1.0992 - val_accuracy: 0.3200
# Epoch 19/50
# 23/23 [==============================] - 0s 9ms/step - loss: 1.0990 - accuracy: 0.3000 - val_loss: 1.0994 - val_accuracy: 0.3200
# Epoch 20/50
# 23/23 [==============================] - 0s 10ms/step - loss: 1.0987 - accuracy: 0.3311 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 21/50
# 23/23 [==============================] - 0s 10ms/step - loss: 1.0988 - accuracy: 0.3067 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 22/50
# 23/23 [==============================] - 0s 9ms/step - loss: 1.0987 - accuracy: 0.3000 - val_loss: 1.0990 - val_accuracy: 0.3200
# Epoch 23/50
# 23/23 [==============================] - 0s 9ms/step - loss: 1.0988 - accuracy: 0.3044 - val_loss: 1.0991 - val_accuracy: 0.3200
# Epoch 24/50
# 23/23 [==============================] - 0s 10ms/step - loss: 1.0986 - accuracy: 0.3467 - val_loss: 1.0990 - val_accuracy: 0.3200
# Epoch 25/50
# 23/23 [==============================] - 0s 9ms/step - loss: 1.0988 - accuracy: 0.3356 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 26/50
# 23/23 [==============================] - 0s 10ms/step - loss: 1.0989 - accuracy: 0.3356 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 27/50
# 23/23 [==============================] - 0s 9ms/step - loss: 1.0988 - accuracy: 0.3356 - val_loss: 1.0990 - val_accuracy: 0.3200
# Epoch 28/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0987 - accuracy: 0.3356 - val_loss: 1.0991 - val_accuracy: 0.3200
# Epoch 29/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0987 - accuracy: 0.3356 - val_loss: 1.0990 - val_accuracy: 0.3200
# Epoch 30/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0988 - accuracy: 0.3356 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 31/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0989 - accuracy: 0.3356 - val_loss: 1.0993 - val_accuracy: 0.3200
# Epoch 32/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0989 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 33/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0990 - accuracy: 0.3356 - val_loss: 1.0992 - val_accuracy: 0.3200
# Epoch 34/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0990 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 35/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0988 - accuracy: 0.3111 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 36/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0988 - accuracy: 0.2978 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 37/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0988 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 38/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0988 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 39/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0988 - accuracy: 0.3356 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 40/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0989 - accuracy: 0.2956 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 41/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0990 - accuracy: 0.2956 - val_loss: 1.0986 - val_accuracy: 0.3200
# Epoch 42/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 43/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0989 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 44/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0988 - accuracy: 0.3356 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 45/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0987 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 46/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0987 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 47/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0987 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 48/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0989 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3200
# Epoch 49/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0989 - accuracy: 0.3356 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 50/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0988 - accuracy: 0.3356 - val_loss: 1.0991 - val_accuracy: 0.3200
# 322/322 [==============================] - 1s 2ms/step

# %% [markdown]
# # Application à une base de données réelle
#
# Pour mettre en application les notions vues précédemment, téléchargez les données suivantes.

# %%
# !wget acarlier.fr/tp/HA_dataset.csv
# Out:
# --2024-04-02 09:46:44--  http://acarlier.fr/tp/HA_dataset.csv
# Resolving acarlier.fr (acarlier.fr)... 212.194.248.69, 2a02:842a:5e:4701:b48a:fe3:257b:3972
# Connecting to acarlier.fr (acarlier.fr)|212.194.248.69|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://acarlier.fr/tp/HA_dataset.csv [following]
# --2024-04-02 09:46:44--  https://acarlier.fr/tp/HA_dataset.csv
# Connecting to acarlier.fr (acarlier.fr)|212.194.248.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11328 (11K) [application/octet-stream]
# Saving to: ‘HA_dataset.csv’
#
# HA_dataset.csv      100%[===================>]  11.06K  --.-KB/s    in 0s
#
# 2024-04-02 09:46:45 (244 MB/s) - ‘HA_dataset.csv’ saved [11328/11328]

# %%
import csv
from sklearn.model_selection import train_test_split

x = []
y = []

# Lecture du fichier CSV et des données
with open('HA_dataset.csv', 'r') as file:
    reader = csv.reader(file)
    headers = next(reader)  # Ligne d'en-tête
    for row in reader:
        x.append([float(value) for value in row[:-1]])  # Toutes les colonnes à l'exception de la dernières sont les variables d'entrée
        y.append(int(row[-1]))  # La dernière colonne constitue le label à prédire

x = np.array(x)
y = np.array(y)

# Séparation des données en jeux d'apprentissage et de test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Affichage de la dimension des données
print("Dimension de x_train:", x_train.shape)
print("Dimension de y_train:", y_train.shape)
print("Dimension de x_test:", x_test.shape)
print("Dimension de y_test:", y_test.shape)
# Out:
# Dimension de x_train: (242, 13)
# Dimension de y_train: (242,)
# Dimension de x_test: (61, 13)
# Dimension de y_test: (61,)

# %% [markdown]
# Ces données sont issues de https://archive.ics.uci.edu/dataset/45/heart+disease et regroupent des caractéristiques de patients risquant ($y=1$) de développer une attaque cardiaque. Voici les différentes caractéristiques sur lesquelles votre modèle pourra s'appuyer pour établir un pronostic :
# - *age* : Âge du patient
# - *sex* : Sexe du patient (0-1)
# - *exang* : Angine induite par l'exercice (1 = oui ; 0 = non)
# - *ca* : Nombre de vaisseaux principaux (0-3)
# - *cp* : Type de douleur thoracique (1-4)
# - *trestbps* : Pression artérielle au repos (en mm de mercure)
# - *chol* : Cholestérol en mg/dl récupéré via un capteur BMI
# - *fbs* : (glycémie à jeun > 120 mg/dl) (1 = vrai ; 0 = faux)
# - *restecg* : Résultats électrocardiographiques au repos (0-2)
# - *thalach* : Fréquence cardiaque maximale atteinte
# - *oldpeak* : Dépression du segment ST induite par l'exercice par rapport au repos
# - *slope*, *thal* : signification non renseignée

# %% [markdown]
# **Travail à faire** : Construisez un classifieur permettant d'obtenir les meilleurs résultats possibles sur l'ensemble de test de ce jeu de données.
#
#
# **N.B.** Prenez garde à l'échelle des données d'entrée ! Le code ci-dessous vous permettra de les répresenter sous forme graphique. Il peut être intéressant de les normaliser...

# %%
import matplotlib.pyplot as plt


combined_data = np.column_stack((x_train, y_train))
combined_data_transposed = list(map(list, zip(*combined_data)))

# Création d'un "diagramme à moustache"
plt.figure(figsize=(10, 6))
plt.boxplot(combined_data_transposed, labels=headers[:-1] + ['target'])
plt.xticks(rotation=45)
plt.title('Distribution des valeurs de chacune des variables')
plt.xlabel('Variables')
plt.ylabel('Valeurs')
plt.yscale('log')  # Echelle logarithmique

plt.grid(True)
plt.tight_layout()
plt.show()
